# %% [markdown]
# CoroNet: COVID19 Chest XRays classification model
# By Dr Asif Iqbal Khan
#
#
# The model uses Xception/InceptionResNetV2/NasNet as base model pre-trained on ImageNet, retrained on Chest X-rays dataset

# %% [markdown]
# Mount Google Drive to load models containing X-ray images in personal folder

# %%
# Mount Google Drive by importing drive from google colab
# Get the authorization code for connecting to user's drive to mount

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Copy dataset folder from Google Drive

# !cp -R /content/drive/"My Drive"/DATASET/covid-19 /content

# %%
#import libraries and packages

from numpy.random import seed
seed(8) #1

import tensorflow
tensorflow.random.set_seed(7)

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

import os

from tensorflow.keras import backend as K
from tensorflow.keras.models import Model ,load_model
from tensorflow.keras.layers import Flatten, Dense, Dropout
from tensorflow.keras.applications.inception_resnet_v2 import InceptionResNetV2, preprocess_input
from keras.applications.vgg16 import preprocess_input
from keras.applications.vgg16 import decode_predictions
from keras.applications.vgg16 import VGG16
from tensorflow.keras.optimizers import Adam, RMSprop
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ModelCheckpoint
import numpy as np
import tensorflow as tf

from tensorflow.python.keras import models
from tensorflow.python.keras import layers

from tensorflow.keras import optimizers

# %%
print(os.listdir("/content/"))

#Print and remove zips once done
# Out:
# ['.config', '4-class-Covid19-Mod-Xception.h5', 'drive', 'covid-19', 'sample_data']

# %%
ls covid-19/four_classes/train
# Out:
# covid/  normal/  pneumonia_bacterial/  pneumonia_viral/

# %% [markdown]
# **Crete Data Generators to preprocess and prepare training and validation**

# %%
from os import listdir
#data_list = listdir('/content/covid-19/four_classes/train')
data_list = listdir('/content/drive/My Drive/DATASET/covid-19/four_classes/train')

#Delete some classes that may interfere

print(len(data_list))


DATASET_PATH  = '/content/drive/My Drive/DATASET/covid-19/four_classes/train'
test_dir =  '/content/drive/My Drive/DATASET/covid-19/four_classes/test'
IMAGE_SIZE    = (128, 128)
NUM_CLASSES   = len(data_list)
BATCH_SIZE    = 16  # try reducing batch size or freeze more layers if your GPU runs out of memory
NUM_EPOCHS    = 100
LEARNING_RATE = 0.00001



#Train datagen here is a preprocessor
train_datagen = ImageDataGenerator(rescale=1./255,
                                   rotation_range=50,
                                   featurewise_center = True,
                                   featurewise_std_normalization = True,
                                   width_shift_range=0.2,
                                   height_shift_range=0.2,
                                   shear_range=0.25,
                                   zoom_range=0.1,
                                   zca_whitening = True,
                                   channel_shift_range = 20,
                                   horizontal_flip = True ,
                                   vertical_flip = True ,
                                   validation_split = 0.2,
                                   fill_mode='constant')



# For multiclass use categorical n for binary use binary
train_batches = train_datagen.flow_from_directory(DATASET_PATH,
                                                  target_size=IMAGE_SIZE,
                                                  shuffle=True,
                                                  batch_size=BATCH_SIZE,
                                                  subset = "training",
                                                  seed=42,
                                                  class_mode="categorical"   #For multiclass use categorical n for binary use binary
                                                  )

valid_batches = train_datagen.flow_from_directory(DATASET_PATH,
                                                  target_size=IMAGE_SIZE,
                                                  shuffle=True,
                                                  batch_size=BATCH_SIZE,
                                                  subset = "validation",
                                                  seed=42,
                                                  class_mode="categorical"  #For multiclass use categorical n for binary use binary
                                                 
                                                  )
# Out:
# 4
# Found 1489 images belonging to 4 classes.
# Found 370 images belonging to 4 classes.
# /usr/local/lib/python3.6/dist-packages/keras_preprocessing/image/image_data_generator.py:342: UserWarning: This ImageDataGenerator specifies `zca_whitening` which overrides setting of`featurewise_std_normalization`.
#   warnings.warn('This ImageDataGenerator specifies '

# %%
path="/content/covid-19/four_classes/"
# !ls -a /content/covid-19/four_classes/train/.ipynb_checkpoints
# !rm -R /content/covid-19/four_classes/test/.ipynb_checkpoints 
# !pwd
# Out:
# ls: cannot access '/content/covid-19/four_classes/train/.ipynb_checkpoints': No such file or directory
# rm: cannot remove '/content/covid-19/four_classes/test/.ipynb_checkpoints': No such file or directory
# /content

# %% [markdown]
# Create a new model or Use Pre trained CNN Model and modify according to the need.

# %%
#Simple CNN model based on Xception. Set dense layer neuron count same as the no. of output classes 
#If you wnna use a saved model then skip this step


from tensorflow.keras.applications import Xception

conv_base = Xception(weights='imagenet',
                  include_top=False,
                  input_shape=(128, 128, 3))


conv_base.trainable = True


model = models.Sequential()
model.add(conv_base)




model.add(layers.Flatten())
model.add(layers.Dropout(0.5))
model.add(layers.Dense(512, activation='relu'))
model.add(layers.Dense(4, activation='softmax'))


model.compile(loss='categorical_crossentropy',     #for multiclass use categorical_crossentropy
              
              optimizer=optimizers.Adam(lr=LEARNING_RATE),
              metrics=['acc'])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/xception/xception_weights_tf_dim_ordering_tf_kernels_notop.h5
# 83689472/83683744 [==============================] - 1s 0us/step

# %% [markdown]
# **Load an already saved model (If there is a trained model already saved on drive)**

# %%
#Load saved model from .hs file, otherwise disable this line
#model=load_model('/content/drive/My Drive/Colab Notebooks/4-class-Covid19-Mod-Xception.h5')
print(model.summary())
print(conv_base.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# xception (Functional)        (None, 4, 4, 2048)        20861480
# _________________________________________________________________
# flatten (Flatten)            (None, 32768)             0
# _________________________________________________________________
# dropout (Dropout)            (None, 32768)             0
# _________________________________________________________________
# dense (Dense)                (None, 512)               16777728
# _________________________________________________________________
# dense_1 (Dense)              (None, 4)                 2052
# =================================================================
# Total params: 37,641,260
# Trainable params: 37,586,732
# Non-trainable params: 54,528
# _________________________________________________________________
# None
# Model: "xception"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 128, 128, 3) 0
# __________________________________________________________________________________________________
# block1_conv1 (Conv2D)           (None, 63, 63, 32)   864         input_1[0][0]
# __________________________________________________________________________________________________
# block1_conv1_bn (BatchNormaliza (None, 63, 63, 32)   128         block1_conv1[0][0]
# __________________________________________________________________________________________________
# block1_conv1_act (Activation)   (None, 63, 63, 32)   0           block1_conv1_bn[0][0]
# __________________________________________________________________________________________________
# block1_conv2 (Conv2D)           (None, 61, 61, 64)   18432       block1_conv1_act[0][0]
# __________________________________________________________________________________________________
# block1_conv2_bn (BatchNormaliza (None, 61, 61, 64)   256         block1_conv2[0][0]
# __________________________________________________________________________________________________
# block1_conv2_act (Activation)   (None, 61, 61, 64)   0           block1_conv2_bn[0][0]
# __________________________________________________________________________________________________
# block2_sepconv1 (SeparableConv2 (None, 61, 61, 128)  8768        block1_conv2_act[0][0]
# __________________________________________________________________________________________________
# block2_sepconv1_bn (BatchNormal (None, 61, 61, 128)  512         block2_sepconv1[0][0]
# __________________________________________________________________________________________________
# block2_sepconv2_act (Activation (None, 61, 61, 128)  0           block2_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block2_sepconv2 (SeparableConv2 (None, 61, 61, 128)  17536       block2_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block2_sepconv2_bn (BatchNormal (None, 61, 61, 128)  512         block2_sepconv2[0][0]
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 31, 31, 128)  8192        block1_conv2_act[0][0]
# __________________________________________________________________________________________________
# block2_pool (MaxPooling2D)      (None, 31, 31, 128)  0           block2_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 31, 31, 128)  512         conv2d[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 31, 31, 128)  0           block2_pool[0][0]
#                                                                  batch_normalization[0][0]
# __________________________________________________________________________________________________
# block3_sepconv1_act (Activation (None, 31, 31, 128)  0           add[0][0]
# __________________________________________________________________________________________________
# block3_sepconv1 (SeparableConv2 (None, 31, 31, 256)  33920       block3_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block3_sepconv1_bn (BatchNormal (None, 31, 31, 256)  1024        block3_sepconv1[0][0]
# __________________________________________________________________________________________________
# block3_sepconv2_act (Activation (None, 31, 31, 256)  0           block3_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block3_sepconv2 (SeparableConv2 (None, 31, 31, 256)  67840       block3_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block3_sepconv2_bn (BatchNormal (None, 31, 31, 256)  1024        block3_sepconv2[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 16, 16, 256)  32768       add[0][0]
# __________________________________________________________________________________________________
# block3_pool (MaxPooling2D)      (None, 16, 16, 256)  0           block3_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 16, 16, 256)  1024        conv2d_1[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 16, 16, 256)  0           block3_pool[0][0]
#                                                                  batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# block4_sepconv1_act (Activation (None, 16, 16, 256)  0           add_1[0][0]
# __________________________________________________________________________________________________
# block4_sepconv1 (SeparableConv2 (None, 16, 16, 728)  188672      block4_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block4_sepconv1_bn (BatchNormal (None, 16, 16, 728)  2912        block4_sepconv1[0][0]
# __________________________________________________________________________________________________
# block4_sepconv2_act (Activation (None, 16, 16, 728)  0           block4_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block4_sepconv2 (SeparableConv2 (None, 16, 16, 728)  536536      block4_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block4_sepconv2_bn (BatchNormal (None, 16, 16, 728)  2912        block4_sepconv2[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 8, 8, 728)    186368      add_1[0][0]
# __________________________________________________________________________________________________
# block4_pool (MaxPooling2D)      (None, 8, 8, 728)    0           block4_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 8, 8, 728)    2912        conv2d_2[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 8, 8, 728)    0           block4_pool[0][0]
#                                                                  batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# block5_sepconv1_act (Activation (None, 8, 8, 728)    0           add_2[0][0]
# __________________________________________________________________________________________________
# block5_sepconv1 (SeparableConv2 (None, 8, 8, 728)    536536      block5_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block5_sepconv1_bn (BatchNormal (None, 8, 8, 728)    2912        block5_sepconv1[0][0]
# __________________________________________________________________________________________________
# block5_sepconv2_act (Activation (None, 8, 8, 728)    0           block5_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block5_sepconv2 (SeparableConv2 (None, 8, 8, 728)    536536      block5_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block5_sepconv2_bn (BatchNormal (None, 8, 8, 728)    2912        block5_sepconv2[0][0]
# __________________________________________________________________________________________________
# block5_sepconv3_act (Activation (None, 8, 8, 728)    0           block5_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block5_sepconv3 (SeparableConv2 (None, 8, 8, 728)    536536      block5_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block5_sepconv3_bn (BatchNormal (None, 8, 8, 728)    2912        block5_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 8, 8, 728)    0           block5_sepconv3_bn[0][0]
#                                                                  add_2[0][0]
# __________________________________________________________________________________________________
# block6_sepconv1_act (Activation (None, 8, 8, 728)    0           add_3[0][0]
# __________________________________________________________________________________________________
# block6_sepconv1 (SeparableConv2 (None, 8, 8, 728)    536536      block6_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block6_sepconv1_bn (BatchNormal (None, 8, 8, 728)    2912        block6_sepconv1[0][0]
# __________________________________________________________________________________________________
# block6_sepconv2_act (Activation (None, 8, 8, 728)    0           block6_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block6_sepconv2 (SeparableConv2 (None, 8, 8, 728)    536536      block6_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block6_sepconv2_bn (BatchNormal (None, 8, 8, 728)    2912        block6_sepconv2[0][0]
# __________________________________________________________________________________________________
# block6_sepconv3_act (Activation (None, 8, 8, 728)    0           block6_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block6_sepconv3 (SeparableConv2 (None, 8, 8, 728)    536536      block6_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block6_sepconv3_bn (BatchNormal (None, 8, 8, 728)    2912        block6_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 8, 8, 728)    0           block6_sepconv3_bn[0][0]
#                                                                  add_3[0][0]
# __________________________________________________________________________________________________
# block7_sepconv1_act (Activation (None, 8, 8, 728)    0           add_4[0][0]
# __________________________________________________________________________________________________
# block7_sepconv1 (SeparableConv2 (None, 8, 8, 728)    536536      block7_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block7_sepconv1_bn (BatchNormal (None, 8, 8, 728)    2912        block7_sepconv1[0][0]
# __________________________________________________________________________________________________
# block7_sepconv2_act (Activation (None, 8, 8, 728)    0           block7_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block7_sepconv2 (SeparableConv2 (None, 8, 8, 728)    536536      block7_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block7_sepconv2_bn (BatchNormal (None, 8, 8, 728)    2912        block7_sepconv2[0][0]
# __________________________________________________________________________________________________
# block7_sepconv3_act (Activation (None, 8, 8, 728)    0           block7_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block7_sepconv3 (SeparableConv2 (None, 8, 8, 728)    536536      block7_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block7_sepconv3_bn (BatchNormal (None, 8, 8, 728)    2912        block7_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 8, 8, 728)    0           block7_sepconv3_bn[0][0]
#                                                                  add_4[0][0]
# __________________________________________________________________________________________________
# block8_sepconv1_act (Activation (None, 8, 8, 728)    0           add_5[0][0]
# __________________________________________________________________________________________________
# block8_sepconv1 (SeparableConv2 (None, 8, 8, 728)    536536      block8_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block8_sepconv1_bn (BatchNormal (None, 8, 8, 728)    2912        block8_sepconv1[0][0]
# __________________________________________________________________________________________________
# block8_sepconv2_act (Activation (None, 8, 8, 728)    0           block8_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block8_sepconv2 (SeparableConv2 (None, 8, 8, 728)    536536      block8_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block8_sepconv2_bn (BatchNormal (None, 8, 8, 728)    2912        block8_sepconv2[0][0]
# __________________________________________________________________________________________________
# block8_sepconv3_act (Activation (None, 8, 8, 728)    0           block8_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block8_sepconv3 (SeparableConv2 (None, 8, 8, 728)    536536      block8_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block8_sepconv3_bn (BatchNormal (None, 8, 8, 728)    2912        block8_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 8, 8, 728)    0           block8_sepconv3_bn[0][0]
#                                                                  add_5[0][0]
# __________________________________________________________________________________________________
# block9_sepconv1_act (Activation (None, 8, 8, 728)    0           add_6[0][0]
# __________________________________________________________________________________________________
# block9_sepconv1 (SeparableConv2 (None, 8, 8, 728)    536536      block9_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block9_sepconv1_bn (BatchNormal (None, 8, 8, 728)    2912        block9_sepconv1[0][0]
# __________________________________________________________________________________________________
# block9_sepconv2_act (Activation (None, 8, 8, 728)    0           block9_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block9_sepconv2 (SeparableConv2 (None, 8, 8, 728)    536536      block9_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block9_sepconv2_bn (BatchNormal (None, 8, 8, 728)    2912        block9_sepconv2[0][0]
# __________________________________________________________________________________________________
# block9_sepconv3_act (Activation (None, 8, 8, 728)    0           block9_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block9_sepconv3 (SeparableConv2 (None, 8, 8, 728)    536536      block9_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block9_sepconv3_bn (BatchNormal (None, 8, 8, 728)    2912        block9_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 8, 8, 728)    0           block9_sepconv3_bn[0][0]
#                                                                  add_6[0][0]
# __________________________________________________________________________________________________
# block10_sepconv1_act (Activatio (None, 8, 8, 728)    0           add_7[0][0]
# __________________________________________________________________________________________________
# block10_sepconv1 (SeparableConv (None, 8, 8, 728)    536536      block10_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block10_sepconv1_bn (BatchNorma (None, 8, 8, 728)    2912        block10_sepconv1[0][0]
# __________________________________________________________________________________________________
# block10_sepconv2_act (Activatio (None, 8, 8, 728)    0           block10_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block10_sepconv2 (SeparableConv (None, 8, 8, 728)    536536      block10_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block10_sepconv2_bn (BatchNorma (None, 8, 8, 728)    2912        block10_sepconv2[0][0]
# __________________________________________________________________________________________________
# block10_sepconv3_act (Activatio (None, 8, 8, 728)    0           block10_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block10_sepconv3 (SeparableConv (None, 8, 8, 728)    536536      block10_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block10_sepconv3_bn (BatchNorma (None, 8, 8, 728)    2912        block10_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 8, 8, 728)    0           block10_sepconv3_bn[0][0]
#                                                                  add_7[0][0]
# __________________________________________________________________________________________________
# block11_sepconv1_act (Activatio (None, 8, 8, 728)    0           add_8[0][0]
# __________________________________________________________________________________________________
# block11_sepconv1 (SeparableConv (None, 8, 8, 728)    536536      block11_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block11_sepconv1_bn (BatchNorma (None, 8, 8, 728)    2912        block11_sepconv1[0][0]
# __________________________________________________________________________________________________
# block11_sepconv2_act (Activatio (None, 8, 8, 728)    0           block11_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block11_sepconv2 (SeparableConv (None, 8, 8, 728)    536536      block11_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block11_sepconv2_bn (BatchNorma (None, 8, 8, 728)    2912        block11_sepconv2[0][0]
# __________________________________________________________________________________________________
# block11_sepconv3_act (Activatio (None, 8, 8, 728)    0           block11_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block11_sepconv3 (SeparableConv (None, 8, 8, 728)    536536      block11_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block11_sepconv3_bn (BatchNorma (None, 8, 8, 728)    2912        block11_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 8, 8, 728)    0           block11_sepconv3_bn[0][0]
#                                                                  add_8[0][0]
# __________________________________________________________________________________________________
# block12_sepconv1_act (Activatio (None, 8, 8, 728)    0           add_9[0][0]
# __________________________________________________________________________________________________
# block12_sepconv1 (SeparableConv (None, 8, 8, 728)    536536      block12_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block12_sepconv1_bn (BatchNorma (None, 8, 8, 728)    2912        block12_sepconv1[0][0]
# __________________________________________________________________________________________________
# block12_sepconv2_act (Activatio (None, 8, 8, 728)    0           block12_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block12_sepconv2 (SeparableConv (None, 8, 8, 728)    536536      block12_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block12_sepconv2_bn (BatchNorma (None, 8, 8, 728)    2912        block12_sepconv2[0][0]
# __________________________________________________________________________________________________
# block12_sepconv3_act (Activatio (None, 8, 8, 728)    0           block12_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block12_sepconv3 (SeparableConv (None, 8, 8, 728)    536536      block12_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block12_sepconv3_bn (BatchNorma (None, 8, 8, 728)    2912        block12_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 8, 8, 728)    0           block12_sepconv3_bn[0][0]
#                                                                  add_9[0][0]
# __________________________________________________________________________________________________
# block13_sepconv1_act (Activatio (None, 8, 8, 728)    0           add_10[0][0]
# __________________________________________________________________________________________________
# block13_sepconv1 (SeparableConv (None, 8, 8, 728)    536536      block13_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block13_sepconv1_bn (BatchNorma (None, 8, 8, 728)    2912        block13_sepconv1[0][0]
# __________________________________________________________________________________________________
# block13_sepconv2_act (Activatio (None, 8, 8, 728)    0           block13_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block13_sepconv2 (SeparableConv (None, 8, 8, 1024)   752024      block13_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block13_sepconv2_bn (BatchNorma (None, 8, 8, 1024)   4096        block13_sepconv2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 4, 4, 1024)   745472      add_10[0][0]
# __________________________________________________________________________________________________
# block13_pool (MaxPooling2D)     (None, 4, 4, 1024)   0           block13_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 4, 4, 1024)   4096        conv2d_3[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 4, 4, 1024)   0           block13_pool[0][0]
#                                                                  batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# block14_sepconv1 (SeparableConv (None, 4, 4, 1536)   1582080     add_11[0][0]
# __________________________________________________________________________________________________
# block14_sepconv1_bn (BatchNorma (None, 4, 4, 1536)   6144        block14_sepconv1[0][0]
# __________________________________________________________________________________________________
# block14_sepconv1_act (Activatio (None, 4, 4, 1536)   0           block14_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block14_sepconv2 (SeparableConv (None, 4, 4, 2048)   3159552     block14_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block14_sepconv2_bn (BatchNorma (None, 4, 4, 2048)   8192        block14_sepconv2[0][0]
# __________________________________________________________________________________________________
# block14_sepconv2_act (Activatio (None, 4, 4, 2048)   0           block14_sepconv2_bn[0][0]
# ==================================================================================================
# Total params: 20,861,480
# Trainable params: 20,806,952
# Non-trainable params: 54,528
# __________________________________________________________________________________________________
# None

# %% [markdown]
# Training

# %%
#FIT MODEL
print(len(train_batches))
print(len(valid_batches))

STEP_SIZE_TRAIN=train_batches.n//train_batches.batch_size
STEP_SIZE_VALID=valid_batches.n//valid_batches.batch_size

result=model.fit_generator(train_batches,
                        steps_per_epoch =STEP_SIZE_TRAIN,
                        validation_data = valid_batches,
                        validation_steps = STEP_SIZE_VALID,
                        epochs= NUM_EPOCHS,                        
                       )
# Out:
# 94
# 24
# WARNING:tensorflow:From <ipython-input-10-378e3394e2b9>:12: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# /usr/local/lib/python3.6/dist-packages/keras_preprocessing/image/image_data_generator.py:720: UserWarning: This ImageDataGenerator specifies `featurewise_center`, but it hasn't been fit on any training data. Fit it first by calling `.fit(numpy_data)`.
#   warnings.warn('This ImageDataGenerator specifies '
# /usr/local/lib/python3.6/dist-packages/keras_preprocessing/image/image_data_generator.py:739: UserWarning: This ImageDataGenerator specifies `zca_whitening`, but it hasn't been fit on any training data. Fit it first by calling `.fit(numpy_data)`.
#   warnings.warn('This ImageDataGenerator specifies '
# Epoch 1/100
#  2/93 [..............................] - ETA: 10s - loss: 1.4678 - acc: 0.2812WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0847s vs `on_train_batch_end` time: 0.1514s). Check your callbacks.
# 93/93 [==============================] - 52s 564ms/step - loss: 1.2598 - acc: 0.4610 - val_loss: 1.2395 - val_acc: 0.4918
# Epoch 2/100
# 93/93 [==============================] - 52s 561ms/step - loss: 1.0838 - acc: 0.5499 - val_loss: 1.0090 - val_acc: 0.5951
# Epoch 3/100
# 93/93 [==============================] - 52s 561ms/step - loss: 0.9896 - acc: 0.6083 - val_loss: 0.9879 - val_acc: 0.5598
# Epoch 4/100
# 93/93 [==============================] - 52s 561ms/step - loss: 0.8556 - acc: 0.6694 - val_loss: 0.7496 - val_acc: 0.6984
# Epoch 5/100
# 93/93 [==============================] - 52s 563ms/step - loss: 0.7803 - acc: 0.6979 - val_loss: 0.7722 - val_acc: 0.6685
# Epoch 6/100
# 93/93 [==============================] - 52s 562ms/step - loss: 0.7445 - acc: 0.7122 - val_loss: 0.7164 - val_acc: 0.7337
# Epoch 7/100
# 93/93 [==============================] - 52s 560ms/step - loss: 0.6851 - acc: 0.7468 - val_loss: 0.5989 - val_acc: 0.7636
# Epoch 8/100
# 93/93 [==============================] - 52s 558ms/step - loss: 0.6219 - acc: 0.7475 - val_loss: 0.5513 - val_acc: 0.7989
# Epoch 9/100
# 93/93 [==============================] - 51s 553ms/step - loss: 0.6197 - acc: 0.7590 - val_loss: 0.6593 - val_acc: 0.7908
# Epoch 10/100
# 93/93 [==============================] - 52s 558ms/step - loss: 0.5600 - acc: 0.7889 - val_loss: 0.5263 - val_acc: 0.7908
# Epoch 11/100
# 93/93 [==============================] - 53s 571ms/step - loss: 0.5556 - acc: 0.8031 - val_loss: 0.5818 - val_acc: 0.7962
# Epoch 12/100
# 93/93 [==============================] - 52s 563ms/step - loss: 0.5482 - acc: 0.7800 - val_loss: 0.5915 - val_acc: 0.7989
# Epoch 13/100
# 93/93 [==============================] - 52s 560ms/step - loss: 0.5273 - acc: 0.8058 - val_loss: 0.5456 - val_acc: 0.8125
# Epoch 14/100
# 93/93 [==============================] - 52s 560ms/step - loss: 0.5318 - acc: 0.8018 - val_loss: 0.5468 - val_acc: 0.7989
# Epoch 15/100
# 93/93 [==============================] - 52s 558ms/step - loss: 0.5143 - acc: 0.8024 - val_loss: 0.5027 - val_acc: 0.8234
# Epoch 16/100
# 93/93 [==============================] - 52s 557ms/step - loss: 0.4887 - acc: 0.8065 - val_loss: 0.5175 - val_acc: 0.8016
# Epoch 17/100
# 93/93 [==============================] - 53s 565ms/step - loss: 0.4852 - acc: 0.8159 - val_loss: 0.4881 - val_acc: 0.8207
# Epoch 18/100
# 93/93 [==============================] - 52s 561ms/step - loss: 0.4432 - acc: 0.8337 - val_loss: 0.5628 - val_acc: 0.8152
# Epoch 19/100
# 93/93 [==============================] - 52s 561ms/step - loss: 0.4576 - acc: 0.8262 - val_loss: 0.5704 - val_acc: 0.8125
# Epoch 20/100
# 93/93 [==============================] - 52s 563ms/step - loss: 0.4345 - acc: 0.8391 - val_loss: 0.4648 - val_acc: 0.8288
# Epoch 21/100
# 93/93 [==============================] - 52s 561ms/step - loss: 0.4609 - acc: 0.8119 - val_loss: 0.4801 - val_acc: 0.8125
# Epoch 22/100
# 93/93 [==============================] - 52s 554ms/step - loss: 0.4296 - acc: 0.8384 - val_loss: 0.5161 - val_acc: 0.8098
# Epoch 23/100
# 93/93 [==============================] - 52s 558ms/step - loss: 0.4488 - acc: 0.8303 - val_loss: 0.3878 - val_acc: 0.8478
# Epoch 24/100
# 93/93 [==============================] - 52s 559ms/step - loss: 0.4116 - acc: 0.8479 - val_loss: 0.4256 - val_acc: 0.8397
# Epoch 25/100
# 93/93 [==============================] - 52s 556ms/step - loss: 0.4252 - acc: 0.8323 - val_loss: 0.4401 - val_acc: 0.8288
# Epoch 26/100
# 93/93 [==============================] - 52s 557ms/step - loss: 0.4094 - acc: 0.8296 - val_loss: 0.4147 - val_acc: 0.8207
# Epoch 27/100
# 93/93 [==============================] - 52s 555ms/step - loss: 0.4032 - acc: 0.8479 - val_loss: 0.4071 - val_acc: 0.8560
# Epoch 28/100
# 93/93 [==============================] - 51s 552ms/step - loss: 0.4115 - acc: 0.8432 - val_loss: 0.4162 - val_acc: 0.8315
# Epoch 29/100
# 93/93 [==============================] - 51s 550ms/step - loss: 0.3971 - acc: 0.8418 - val_loss: 0.3825 - val_acc: 0.8533
# Epoch 30/100
# 93/93 [==============================] - 52s 557ms/step - loss: 0.4135 - acc: 0.8439 - val_loss: 0.4618 - val_acc: 0.8370
# Epoch 31/100
# 93/93 [==============================] - 52s 561ms/step - loss: 0.3702 - acc: 0.8608 - val_loss: 0.4410 - val_acc: 0.8451
# Epoch 32/100
# 93/93 [==============================] - 52s 561ms/step - loss: 0.3920 - acc: 0.8527 - val_loss: 0.4483 - val_acc: 0.8505
# Epoch 33/100
# 93/93 [==============================] - 52s 561ms/step - loss: 0.4254 - acc: 0.8439 - val_loss: 0.3895 - val_acc: 0.8478
# Epoch 34/100
# 93/93 [==============================] - 52s 563ms/step - loss: 0.3880 - acc: 0.8418 - val_loss: 0.4065 - val_acc: 0.8614
# Epoch 35/100
# 93/93 [==============================] - 53s 566ms/step - loss: 0.3859 - acc: 0.8527 - val_loss: 0.4387 - val_acc: 0.8505
# Epoch 36/100
# 93/93 [==============================] - 53s 566ms/step - loss: 0.3727 - acc: 0.8629 - val_loss: 0.4234 - val_acc: 0.8505
# Epoch 37/100
# 93/93 [==============================] - 53s 567ms/step - loss: 0.3503 - acc: 0.8588 - val_loss: 0.4064 - val_acc: 0.8614
# Epoch 38/100
# 93/93 [==============================] - 52s 559ms/step - loss: 0.3819 - acc: 0.8574 - val_loss: 0.4331 - val_acc: 0.8261
# Epoch 39/100
# 93/93 [==============================] - 51s 543ms/step - loss: 0.3426 - acc: 0.8703 - val_loss: 0.3410 - val_acc: 0.8533
# Epoch 40/100
# 93/93 [==============================] - 51s 552ms/step - loss: 0.3419 - acc: 0.8703 - val_loss: 0.4936 - val_acc: 0.8071
# Epoch 41/100
# 93/93 [==============================] - 52s 555ms/step - loss: 0.3491 - acc: 0.8710 - val_loss: 0.4036 - val_acc: 0.8533
# Epoch 42/100
# 93/93 [==============================] - 53s 567ms/step - loss: 0.3271 - acc: 0.8683 - val_loss: 0.3743 - val_acc: 0.8641
# Epoch 43/100
# 93/93 [==============================] - 52s 559ms/step - loss: 0.3378 - acc: 0.8595 - val_loss: 0.4373 - val_acc: 0.8342
# Epoch 44/100
# 93/93 [==============================] - 52s 560ms/step - loss: 0.3358 - acc: 0.8717 - val_loss: 0.4068 - val_acc: 0.8505
# Epoch 45/100
# 93/93 [==============================] - 52s 561ms/step - loss: 0.3690 - acc: 0.8608 - val_loss: 0.3974 - val_acc: 0.8723
# Epoch 46/100
# 93/93 [==============================] - 52s 561ms/step - loss: 0.3296 - acc: 0.8798 - val_loss: 0.3773 - val_acc: 0.8451
# Epoch 47/100
# 93/93 [==============================] - 52s 563ms/step - loss: 0.3272 - acc: 0.8792 - val_loss: 0.3659 - val_acc: 0.8832
# Epoch 48/100
# 93/93 [==============================] - 52s 561ms/step - loss: 0.3211 - acc: 0.8771 - val_loss: 0.3763 - val_acc: 0.8668
# Epoch 49/100
# 93/93 [==============================] - 52s 561ms/step - loss: 0.3406 - acc: 0.8771 - val_loss: 0.4069 - val_acc: 0.8750
# Epoch 50/100
# 93/93 [==============================] - 52s 559ms/step - loss: 0.2842 - acc: 0.8921 - val_loss: 0.3645 - val_acc: 0.8723
# Epoch 51/100
# 93/93 [==============================] - 52s 556ms/step - loss: 0.3330 - acc: 0.8710 - val_loss: 0.3562 - val_acc: 0.8886
# Epoch 52/100
# 93/93 [==============================] - 51s 546ms/step - loss: 0.3023 - acc: 0.8880 - val_loss: 0.4515 - val_acc: 0.8234
# Epoch 53/100
# 93/93 [==============================] - 51s 544ms/step - loss: 0.3007 - acc: 0.8819 - val_loss: 0.3780 - val_acc: 0.8614
# Epoch 54/100
# 93/93 [==============================] - 50s 541ms/step - loss: 0.2863 - acc: 0.8751 - val_loss: 0.4182 - val_acc: 0.8668
# Epoch 55/100
# 93/93 [==============================] - 51s 549ms/step - loss: 0.3077 - acc: 0.8792 - val_loss: 0.3803 - val_acc: 0.8696
# Epoch 56/100
# 93/93 [==============================] - 51s 552ms/step - loss: 0.3302 - acc: 0.8758 - val_loss: 0.4031 - val_acc: 0.8478
# Epoch 57/100
# 93/93 [==============================] - 51s 552ms/step - loss: 0.3384 - acc: 0.8744 - val_loss: 0.3605 - val_acc: 0.8587
# Epoch 58/100
# 93/93 [==============================] - 52s 556ms/step - loss: 0.3075 - acc: 0.8826 - val_loss: 0.4208 - val_acc: 0.8641
# Epoch 59/100
# 93/93 [==============================] - 52s 555ms/step - loss: 0.3265 - acc: 0.8798 - val_loss: 0.4170 - val_acc: 0.8668
# Epoch 60/100
# 93/93 [==============================] - 51s 552ms/step - loss: 0.3265 - acc: 0.8737 - val_loss: 0.3736 - val_acc: 0.8614
# Epoch 61/100
# 93/93 [==============================] - 52s 554ms/step - loss: 0.2937 - acc: 0.8934 - val_loss: 0.3984 - val_acc: 0.8940
# Epoch 62/100
# 93/93 [==============================] - 52s 559ms/step - loss: 0.2748 - acc: 0.8948 - val_loss: 0.3816 - val_acc: 0.8668
# Epoch 63/100
# 93/93 [==============================] - 52s 560ms/step - loss: 0.2719 - acc: 0.9022 - val_loss: 0.3776 - val_acc: 0.8478
# Epoch 64/100
# 93/93 [==============================] - 52s 558ms/step - loss: 0.2758 - acc: 0.8866 - val_loss: 0.3515 - val_acc: 0.8723
# Epoch 65/100
# 93/93 [==============================] - 52s 560ms/step - loss: 0.3030 - acc: 0.8844 - val_loss: 0.4133 - val_acc: 0.8614
# Epoch 66/100
# 93/93 [==============================] - 51s 553ms/step - loss: 0.2984 - acc: 0.8893 - val_loss: 0.3522 - val_acc: 0.8696
# Epoch 67/100
# 93/93 [==============================] - 52s 557ms/step - loss: 0.2871 - acc: 0.8955 - val_loss: 0.3950 - val_acc: 0.8777
# Epoch 68/100
# 93/93 [==============================] - 52s 558ms/step - loss: 0.2525 - acc: 0.9043 - val_loss: 0.3803 - val_acc: 0.8723
# Epoch 69/100
# 93/93 [==============================] - 51s 546ms/step - loss: 0.2889 - acc: 0.8934 - val_loss: 0.3889 - val_acc: 0.8668
# Epoch 70/100
# 93/93 [==============================] - 51s 546ms/step - loss: 0.2681 - acc: 0.9050 - val_loss: 0.3980 - val_acc: 0.8696
# Epoch 71/100
# 93/93 [==============================] - 52s 557ms/step - loss: 0.2700 - acc: 0.9036 - val_loss: 0.4125 - val_acc: 0.8587
# Epoch 72/100
# 93/93 [==============================] - 52s 557ms/step - loss: 0.2618 - acc: 0.8961 - val_loss: 0.3971 - val_acc: 0.8777
# Epoch 73/100
# 93/93 [==============================] - 52s 557ms/step - loss: 0.2761 - acc: 0.8968 - val_loss: 0.4083 - val_acc: 0.8424
# Epoch 74/100
# 93/93 [==============================] - 52s 557ms/step - loss: 0.2694 - acc: 0.8968 - val_loss: 0.4237 - val_acc: 0.8505
# Epoch 75/100
# 93/93 [==============================] - 52s 560ms/step - loss: 0.2284 - acc: 0.9063 - val_loss: 0.3489 - val_acc: 0.8859
# Epoch 76/100
# 93/93 [==============================] - 52s 558ms/step - loss: 0.2882 - acc: 0.8968 - val_loss: 0.4114 - val_acc: 0.8750
# Epoch 77/100
# 93/93 [==============================] - 52s 562ms/step - loss: 0.2677 - acc: 0.9036 - val_loss: 0.4454 - val_acc: 0.8478
# Epoch 78/100
# 93/93 [==============================] - 52s 559ms/step - loss: 0.2641 - acc: 0.9029 - val_loss: 0.3712 - val_acc: 0.8696
# Epoch 79/100
# 93/93 [==============================] - 52s 564ms/step - loss: 0.2473 - acc: 0.8988 - val_loss: 0.3899 - val_acc: 0.8478
# Epoch 80/100
# 93/93 [==============================] - 52s 561ms/step - loss: 0.2418 - acc: 0.9070 - val_loss: 0.3853 - val_acc: 0.8533
# Epoch 81/100
# 93/93 [==============================] - 52s 562ms/step - loss: 0.2477 - acc: 0.9022 - val_loss: 0.3531 - val_acc: 0.8886
# Epoch 82/100
# 93/93 [==============================] - 52s 555ms/step - loss: 0.2486 - acc: 0.8995 - val_loss: 0.3994 - val_acc: 0.8560
# Epoch 83/100
# 93/93 [==============================] - 52s 557ms/step - loss: 0.2384 - acc: 0.9158 - val_loss: 0.3747 - val_acc: 0.8777
# Epoch 84/100
# 93/93 [==============================] - 51s 552ms/step - loss: 0.2322 - acc: 0.9050 - val_loss: 0.3939 - val_acc: 0.8560
# Epoch 85/100
# 93/93 [==============================] - 52s 558ms/step - loss: 0.2551 - acc: 0.9063 - val_loss: 0.3327 - val_acc: 0.8832
# Epoch 86/100
# 93/93 [==============================] - 52s 559ms/step - loss: 0.2453 - acc: 0.9077 - val_loss: 0.3600 - val_acc: 0.8804
# Epoch 87/100
# 93/93 [==============================] - 52s 564ms/step - loss: 0.2327 - acc: 0.9111 - val_loss: 0.3791 - val_acc: 0.8859
# Epoch 88/100
# 93/93 [==============================] - 52s 559ms/step - loss: 0.2353 - acc: 0.9090 - val_loss: 0.4226 - val_acc: 0.8641
# Epoch 89/100
# 93/93 [==============================] - 52s 557ms/step - loss: 0.2533 - acc: 0.9009 - val_loss: 0.4258 - val_acc: 0.8668
# Epoch 90/100
# 93/93 [==============================] - 51s 552ms/step - loss: 0.2286 - acc: 0.9104 - val_loss: 0.4239 - val_acc: 0.8533
# Epoch 91/100
# 93/93 [==============================] - 51s 551ms/step - loss: 0.2362 - acc: 0.9097 - val_loss: 0.3514 - val_acc: 0.8804
# Epoch 92/100
# 93/93 [==============================] - 52s 554ms/step - loss: 0.2324 - acc: 0.9104 - val_loss: 0.4335 - val_acc: 0.8777
# Epoch 93/100
# 93/93 [==============================] - 52s 561ms/step - loss: 0.2383 - acc: 0.9050 - val_loss: 0.3573 - val_acc: 0.8995
# Epoch 94/100
# 93/93 [==============================] - 52s 556ms/step - loss: 0.2316 - acc: 0.9084 - val_loss: 0.3707 - val_acc: 0.8859
# Epoch 95/100
# 93/93 [==============================] - 51s 553ms/step - loss: 0.2108 - acc: 0.9246 - val_loss: 0.3710 - val_acc: 0.8804
# Epoch 96/100
# 93/93 [==============================] - 53s 568ms/step - loss: 0.2360 - acc: 0.9131 - val_loss: 0.3816 - val_acc: 0.8832
# Epoch 97/100
# 93/93 [==============================] - 52s 561ms/step - loss: 0.2138 - acc: 0.9158 - val_loss: 0.3309 - val_acc: 0.8940
# Epoch 98/100
# 93/93 [==============================] - 52s 560ms/step - loss: 0.2378 - acc: 0.9124 - val_loss: 0.4978 - val_acc: 0.8478
# Epoch 99/100
# 93/93 [==============================] - 52s 559ms/step - loss: 0.2271 - acc: 0.9165 - val_loss: 0.3198 - val_acc: 0.8859
# Epoch 100/100
# 93/93 [==============================] - 51s 553ms/step - loss: 0.2031 - acc: 0.9212 - val_loss: 0.4209 - val_acc: 0.8641

# %% [markdown]
# Evaluation

# %%
#Plot the accuracy and loss graphs

import matplotlib.pyplot as plt


def plot_acc_loss(result, epochs):
    acc = result.history['acc']
    loss = result.history['loss']
    val_acc = result.history['val_acc']
    val_loss = result.history['val_loss']
    plt.figure(figsize=(15, 5))
    plt.subplot(121)
    plt.plot(range(1,epochs), acc[1:], label='Train_acc')
    plt.plot(range(1,epochs), val_acc[1:], label='Val_acc')
    plt.title('Accuracy over ' + str(epochs) + ' Epochs', size=15)
    plt.legend()
    plt.grid(True)
    plt.subplot(122)
    plt.plot(range(1,epochs), loss[1:], label='Train_loss')
    plt.plot(range(1,epochs), val_loss[1:], label='Val_loss')
    plt.title('Loss over ' + str(epochs) + ' Epochs', size=15)
    plt.legend()
    plt.grid(True)
    plt.show()
    
plot_acc_loss(result, 100)

# %%
#Save the trained model and copy to drive

model.save('4-class-Covid19-Mod-Xception.h5')
#!cp /content/"4-class-Covid19-Mod-Xception.h5" /content/drive/"My Drive"/"Colab Notebooks"

# %% [markdown]
# **Evaluate using evaluate Generator**

# %%
# Create evaluate data generator from test set
#Dont forget shuffle false

test_datagen = ImageDataGenerator(rescale=1. / 255)
test_dir =  '/content/drive/My Drive/DATASET/covid-19/four_classes/test'
eval_generator = test_datagen.flow_from_directory(test_dir,target_size=IMAGE_SIZE,batch_size=1, 
                                                  shuffle=False, seed=42, class_mode="categorical")
eval_generator.reset()
# Out:
# Found 280 images belonging to 4 classes.

# %%
#Evalute the trained model on evaluate generator
eval_generator.reset()  
x = model.evaluate_generator(eval_generator,
                           steps = np.ceil(len(eval_generator)), 
                           use_multiprocessing = False,
                           verbose = 1,
                           workers=1,
                           )


print('Test loss:' , x[0])
print('Test accuracy:',x[1])

#Poor test accuracy due to the small dataset size
# Out:
# WARNING:tensorflow:From <ipython-input-14-71e59a5f24d7>:7: Model.evaluate_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.evaluate, which supports generators.
# 280/280 [==============================] - 8s 27ms/step - loss: 0.3943 - acc: 0.8679
# Test loss: 0.3942779302597046
# Test accuracy: 0.8678571581840515

# %% [markdown]
# **Create DataGen on single folder/class and predict !**

# %%
IMAGE_SIZE    = (128, 128)
test_datagen = ImageDataGenerator(rescale=1. / 255)
test_dir =  '/content/drive/My Drive/DATASET/covid-19/four_classes/test'
pred_generator = test_datagen.flow_from_directory(
        test_dir,target_size=IMAGE_SIZE,
        batch_size=1,
        shuffle=False,
        
        seed=42,
        
        class_mode="categorical")
pred_generator.reset()   

count=[0,0,0,0]

files=pred_generator.filenames

for i in range(len(files)):
  x,y = pred_generator.next()
  img = x
  predict=model.predict(img)
  
  p=np.argmax(predict, axis=-1)
  print(str(p[0])+" "+files[pred_generator.batch_index-1])
  #print(predict)
  #p=model.predict_classes(img)
  count[p[0]]+=1
  
#print(str(p[0])+" "+files[i]) 
print(count)
# Out:
# Found 280 images belonging to 4 classes.
# 0 covid/RX-torace-a-letto-del-paziente-in-unica-proiezione-AP-1-1.jpeg
# 1 covid/S1-new.png
# 0 covid/SARS-10.1148rg.242035193-g04mr34g0-Fig8a-day0.jpeg
# 0 covid/SARS-10.1148rg.242035193-g04mr34g0-Fig8b-day5.jpeg
# 0 covid/SARS-10.1148rg.242035193-g04mr34g0-Fig8c-day10.jpeg
# 0 covid/SARS-10.1148rg.242035193-g04mr34g04a-Fig4a-day7.jpeg
# 0 covid/SARS-10.1148rg.242035193-g04mr34g04b-Fig4b-day12.jpeg
# 0 covid/SARS-10.1148rg.242035193-g04mr34g05x-Fig5-day9.jpeg
# 0 covid/SARS-10.1148rg.242035193-g04mr34g07a-Fig7a-day5.jpeg
# 0 covid/SARS-10.1148rg.242035193-g04mr34g07b-Fig7b-day12.jpeg
# 0 covid/SARS-10.1148rg.242035193-g04mr34g09a-Fig9a-day17.jpeg
# 0 covid/SARS-10.1148rg.242035193-g04mr34g09b-Fig9b-day19.jpeg
# 0 covid/SARS-10.1148rg.242035193-g04mr34g09c-Fig9c-day27.jpeg
# 0 covid/X-ray_of_cyst_in_pneumocystis_pneumonia_1.jpg
# 0 covid/radiol.2020201160.fig3b.jpeg
# 0 covid/radiol.2020201160.fig3c.jpeg
# 0 covid/radiol.2020201160.fig3d.jpeg
# 0 covid/radiol.2020201160.fig6b.jpeg
# 0 covid/radiopaedia-2019-novel-coronavirus-infected-pneumonia.jpg
# 0 covid/right-upper-lobe-pneumonia-9-L.jpg
# 0 covid/right-upper-lobe-pneumonia-9-PA.jpg
# 0 covid/ryct.2020200028.fig1a.jpeg
# 0 covid/ryct.2020200034.fig2.jpeg
# 0 covid/ryct.2020200034.fig5-day0.jpeg
# 0 covid/ryct.2020200034.fig5-day4.jpeg
# 0 covid/ryct.2020200034.fig5-day7.jpeg
# 0 covid/streptococcus-pneumoniae-pneumonia-temporal-evolution-1-day0.jpg
# 0 covid/streptococcus-pneumoniae-pneumonia-temporal-evolution-1-day1.jpg
# 0 covid/streptococcus-pneumoniae-pneumonia-temporal-evolution-1-day2.jpg
# 0 covid/streptococcus-pneumoniae-pneumonia-temporal-evolution-1-day3.jpg
# 0 covid/wong-0000.jpg
# 1 covid/wong-0002.jpg
# 0 covid/wong-0003.jpg
# 0 covid/wong-0004.jpg
# 0 covid/wong-0005.jpg
# 1 normal/IM-0497-0001-0001.jpeg
# 1 normal/IM-0497-0001-0002.jpeg
# 1 normal/IM-0499-0001-0001.jpeg
# 1 normal/IM-0499-0001-0002.jpeg
# 1 normal/IM-0499-0001.jpeg
# 1 normal/IM-0500-0001.jpeg
# 1 normal/IM-0501-0001-0001.jpeg
# 1 normal/IM-0501-0001-0002.jpeg
# 1 normal/IM-0501-0001.jpeg
# 1 normal/IM-0503-0001.jpeg
# 1 normal/IM-0504-0001.jpeg
# 1 normal/IM-0505-0001-0001.jpeg
# 1 normal/IM-0505-0001-0002.jpeg
# 1 normal/IM-0505-0001.jpeg
# 1 normal/IM-0506-0001.jpeg
# 1 normal/IM-0507-0001.jpeg
# 1 normal/IM-0508-0001.jpeg
# 1 normal/IM-0509-0001-0001.jpeg
# 1 normal/IM-0509-0001-0002.jpeg
# 1 normal/IM-0509-0001.jpeg
# 1 normal/IM-0510-0001.jpeg
# 1 normal/IM-0511-0001-0001.jpeg
# 1 normal/IM-0511-0001-0002.jpeg
# 1 normal/IM-0511-0001.jpeg
# 1 normal/IM-0512-0001.jpeg
# 1 normal/IM-0513-0001.jpeg
# 1 normal/IM-0514-0001.jpeg
# 1 normal/IM-0515-0001.jpeg
# 1 normal/IM-0516-0001.jpeg
# 1 normal/IM-0517-0001-0001.jpeg
# 0 normal/IM-0517-0001.jpeg
# 1 normal/IM-0519-0001-0001.jpeg
# 1 normal/IM-0519-0001-0002.jpeg
# 1 normal/IM-0519-0001.jpeg
# 1 normal/IM-0520-0001.jpeg
# 1 normal/IM-0521-0001.jpeg
# 1 normal/IM-0522-0001.jpeg
# 1 normal/IM-0523-0001-0001.jpeg
# 1 normal/IM-0523-0001-0002.jpeg
# 1 normal/IM-0523-0001-0003.jpeg
# 1 normal/IM-0523-0001.jpeg
# 1 normal/IM-0588-0001.jpeg
# 1 normal/IM-0590-0001.jpeg
# 1 normal/IM-0591-0001.jpeg
# 1 normal/IM-0592-0001.jpeg
# 1 normal/IM-0593-0001.jpeg
# 1 normal/IM-0595-0001.jpeg
# 1 normal/IM-0596-0001.jpeg
# 1 normal/IM-0598-0001.jpeg
# 1 normal/IM-0599-0001.jpeg
# 1 normal/IM-0600-0001.jpeg
# 1 normal/IM-0601-0001.jpeg
# 1 normal/IM-0602-0001.jpeg
# 1 normal/IM-0604-0001.jpeg
# 1 normal/IM-0605-0001.jpeg
# 1 normal/IM-0606-0001.jpeg
# 1 normal/IM-0607-0001.jpeg
# 1 normal/IM-0608-0001-0001.jpeg
# 1 normal/IM-0608-0001-0002.jpeg
# 1 normal/IM-0608-0001.jpeg
# 1 normal/IM-0609-0001.jpeg
# 1 normal/IM-0612-0001-0001.jpeg
# 1 normal/IM-0612-0001-0002.jpeg
# 1 normal/IM-0612-0001.jpeg
# 1 normal/IM-0613-0001.jpeg
# 1 normal/NORMAL2-IM-0341-0001.jpeg
# 1 normal/NORMAL2-IM-0343-0001.jpeg
# 1 normal/NORMAL2-IM-0345-0001.jpeg
# 1 normal/NORMAL2-IM-0346-0001.jpeg
# 1 normal/NORMAL2-IM-0347-0001.jpeg
# 1 normal/NORMAL2-IM-0348-0001.jpeg
# 1 normal/NORMAL2-IM-0349-0001.jpeg
# 1 normal/NORMAL2-IM-0350-0001.jpeg
# 1 normal/NORMAL2-IM-0351-0001.jpeg
# 1 normal/NORMAL2-IM-0352-0001.jpeg
# 1 normal/NORMAL2-IM-0353-0001.jpeg
# 1 normal/NORMAL2-IM-0354-0001.jpeg
# 1 normal/NORMAL2-IM-0357-0001.jpeg
# 1 normal/NORMAL2-IM-0359-0001.jpeg
# 1 normal/NORMAL2-IM-0360-0001.jpeg
# 1 normal/NORMAL2-IM-0361-0001.jpeg
# 1 normal/NORMAL2-IM-0362-0001.jpeg
# 1 normal/NORMAL2-IM-0364-0001.jpeg
# 1 normal/NORMAL2-IM-0366-0001.jpeg
# 1 normal/NORMAL2-IM-0368-0001.jpeg
# 1 normal/NORMAL2-IM-0369-0001.jpeg
# 1 normal/NORMAL2-IM-0370-0001.jpeg
# 1 normal/NORMAL2-IM-0372-0001.jpeg
# 1 normal/NORMAL2-IM-0373-0001.jpeg
# 1 normal/NORMAL2-IM-0374-0001-0001.jpeg
# 1 normal/NORMAL2-IM-0374-0001-0002.jpeg
# 1 normal/NORMAL2-IM-0374-0001.jpeg
# 1 normal/NORMAL2-IM-0376-0001.jpeg
# 1 normal/NORMAL2-IM-0378-0001.jpeg
# 1 normal/NORMAL2-IM-0380-0001.jpeg
# 1 normal/NORMAL2-IM-0381-0001.jpeg
# 3 normal/NORMAL2-IM-1437-0001.jpeg
# 3 normal/NORMAL2-IM-1438-0001.jpeg
# 1 normal/NORMAL2-IM-1440-0001.jpeg
# 1 normal/NORMAL2-IM-1442-0001.jpeg
# 2 pneumonia_bacterial/person141_bacteria_677.jpeg
# 2 pneumonia_bacterial/person141_bacteria_678.jpeg
# 2 pneumonia_bacterial/person141_bacteria_681.jpeg
# 2 pneumonia_bacterial/person142_bacteria_682.jpeg
# 2 pneumonia_bacterial/person142_bacteria_683.jpeg
# 2 pneumonia_bacterial/person142_bacteria_684.jpeg
# 2 pneumonia_bacterial/person143_bacteria_687.jpeg
# 2 pneumonia_bacterial/person143_bacteria_688.jpeg
# 3 pneumonia_bacterial/person143_bacteria_689.jpeg
# 2 pneumonia_bacterial/person144_bacteria_690.jpeg
# 2 pneumonia_bacterial/person145_bacteria_696.jpeg
# 1 pneumonia_bacterial/person146_bacteria_700.jpeg
# 2 pneumonia_bacterial/person146_bacteria_703.jpeg
# 2 pneumonia_bacterial/person146_bacteria_704.jpeg
# 2 pneumonia_bacterial/person147_bacteria_705.jpeg
# 2 pneumonia_bacterial/person147_bacteria_706.jpeg
# 2 pneumonia_bacterial/person171_bacteria_826.jpeg
# 3 pneumonia_bacterial/person172_bacteria_827.jpeg
# 3 pneumonia_bacterial/person172_bacteria_828.jpeg
# 2 pneumonia_bacterial/person173_bacteria_829.jpeg
# 2 pneumonia_bacterial/person173_bacteria_830.jpeg
# 1 pneumonia_bacterial/person173_bacteria_831.jpeg
# 1 pneumonia_bacterial/person174_bacteria_832.jpeg
# 2 pneumonia_bacterial/person175_bacteria_833.jpeg
# 2 pneumonia_bacterial/person175_bacteria_834.jpeg
# 2 pneumonia_bacterial/person175_bacteria_835.jpeg
# 2 pneumonia_bacterial/person75_bacteria_368.jpeg
# 1 pneumonia_bacterial/person75_bacteria_369.jpeg
# 3 pneumonia_bacterial/person76_bacteria_370.jpeg
# 1 pneumonia_bacterial/person76_bacteria_371.jpeg
# 1 pneumonia_bacterial/person76_bacteria_372.jpeg
# 2 pneumonia_bacterial/person77_bacteria_374.jpeg
# 2 pneumonia_bacterial/person77_bacteria_375.jpeg
# 2 pneumonia_bacterial/person77_bacteria_376.jpeg
# 2 pneumonia_bacterial/person77_bacteria_377.jpeg
# 2 pneumonia_bacterial/person80_bacteria_389.jpeg
# 2 pneumonia_bacterial/person80_bacteria_390.jpeg
# 2 pneumonia_bacterial/person80_bacteria_391.jpeg
# 2 pneumonia_bacterial/person80_bacteria_392.jpeg
# 2 pneumonia_bacterial/person80_bacteria_393.jpeg
# 2 pneumonia_bacterial/person81_bacteria_395.jpeg
# 2 pneumonia_bacterial/person81_bacteria_396.jpeg
# 2 pneumonia_bacterial/person81_bacteria_397.jpeg
# 2 pneumonia_bacterial/person81_bacteria_398.jpeg
# 2 pneumonia_bacterial/person82_bacteria_402.jpeg
# 2 pneumonia_bacterial/person82_bacteria_403.jpeg
# 2 pneumonia_bacterial/person82_bacteria_404.jpeg
# 2 pneumonia_bacterial/person82_bacteria_405.jpeg
# 3 pneumonia_bacterial/person83_bacteria_407.jpeg
# 2 pneumonia_bacterial/person83_bacteria_409.jpeg
# 2 pneumonia_bacterial/person83_bacteria_410.jpeg
# 2 pneumonia_bacterial/person83_bacteria_411.jpeg
# 2 pneumonia_bacterial/person83_bacteria_412.jpeg
# 2 pneumonia_bacterial/person83_bacteria_414.jpeg
# 2 pneumonia_bacterial/person85_bacteria_417.jpeg
# 3 pneumonia_bacterial/person85_bacteria_419.jpeg
# 2 pneumonia_bacterial/person85_bacteria_421.jpeg
# 2 pneumonia_bacterial/person85_bacteria_422.jpeg
# 2 pneumonia_bacterial/person85_bacteria_423.jpeg
# 2 pneumonia_bacterial/person85_bacteria_424.jpeg
# 2 pneumonia_bacterial/person86_bacteria_428.jpeg
# 2 pneumonia_bacterial/person86_bacteria_429.jpeg
# 2 pneumonia_bacterial/person87_bacteria_433.jpeg
# 2 pneumonia_bacterial/person87_bacteria_434.jpeg
# 2 pneumonia_bacterial/person88_bacteria_437.jpeg
# 2 pneumonia_bacterial/person88_bacteria_438.jpeg
# 1 pneumonia_bacterial/person88_bacteria_439.jpeg
# 3 pneumonia_bacterial/person89_bacteria_440.jpeg
# 2 pneumonia_bacterial/person90_bacteria_442.jpeg
# 2 pneumonia_bacterial/person90_bacteria_443.jpeg
# 2 pneumonia_bacterial/person91_bacteria_445.jpeg
# 2 pneumonia_bacterial/person91_bacteria_446.jpeg
# 2 pneumonia_bacterial/person91_bacteria_447.jpeg
# 2 pneumonia_bacterial/person91_bacteria_448.jpeg
# 2 pneumonia_bacterial/person91_bacteria_449.jpeg
# 3 pneumonia_viral/person10_virus_35.jpeg
# 3 pneumonia_viral/person11_virus_38.jpeg
# 3 pneumonia_viral/person14_virus_44.jpeg
# 1 pneumonia_viral/person15_virus_46.jpeg
# 3 pneumonia_viral/person1647_virus_2848.jpeg
# 3 pneumonia_viral/person1649_virus_2850.jpeg
# 3 pneumonia_viral/person1650_virus_2852.jpeg
# 3 pneumonia_viral/person1650_virus_2854.jpeg
# 3 pneumonia_viral/person1651_virus_2855.jpeg
# 3 pneumonia_viral/person1653_virus_2858.jpeg
# 3 pneumonia_viral/person1653_virus_2859.jpeg
# 3 pneumonia_viral/person1655_virus_2861.jpeg
# 3 pneumonia_viral/person1656_virus_2862.jpeg
# 3 pneumonia_viral/person1657_virus_2864.jpeg
# 3 pneumonia_viral/person1659_virus_2867.jpeg
# 3 pneumonia_viral/person1660_virus_2869.jpeg
# 2 pneumonia_viral/person1661_virus_2872.jpeg
# 2 pneumonia_viral/person1661_virus_2873.jpeg
# 3 pneumonia_viral/person1662_virus_2875.jpeg
# 3 pneumonia_viral/person1663_virus_2876.jpeg
# 3 pneumonia_viral/person1664_virus_2877.jpeg
# 3 pneumonia_viral/person1665_virus_2878.jpeg
# 3 pneumonia_viral/person1667_virus_2881.jpeg
# 3 pneumonia_viral/person1668_virus_2882.jpeg
# 3 pneumonia_viral/person1669_virus_2884.jpeg
# 3 pneumonia_viral/person1669_virus_2885.jpeg
# 3 pneumonia_viral/person1670_virus_2886.jpeg
# 3 pneumonia_viral/person1671_virus_2887.jpeg
# 3 pneumonia_viral/person1672_virus_2888.jpeg
# 3 pneumonia_viral/person1673_virus_2889.jpeg
# 0 pneumonia_viral/person1674_virus_2890.jpeg
# 3 pneumonia_viral/person1675_virus_2891.jpeg
# 3 pneumonia_viral/person1676_virus_2892.jpeg
# 3 pneumonia_viral/person1678_virus_2895.jpeg
# 3 pneumonia_viral/person1679_virus_2896.jpeg
# 3 pneumonia_viral/person1680_virus_2897.jpeg
# 3 pneumonia_viral/person1682_virus_2899.jpeg
# 2 pneumonia_viral/person1685_virus_2903.jpeg
# 0 pneumonia_viral/person16_virus_47.jpeg
# 3 pneumonia_viral/person17_virus_48.jpeg
# 1 pneumonia_viral/person18_virus_49.jpeg
# 1 pneumonia_viral/person19_virus_50.jpeg
# 2 pneumonia_viral/person1_virus_11.jpeg
# 2 pneumonia_viral/person1_virus_12.jpeg
# 3 pneumonia_viral/person1_virus_13.jpeg
# 2 pneumonia_viral/person1_virus_6.jpeg
# 2 pneumonia_viral/person1_virus_7.jpeg
# 2 pneumonia_viral/person1_virus_8.jpeg
# 2 pneumonia_viral/person1_virus_9.jpeg
# 3 pneumonia_viral/person20_virus_51.jpeg
# 3 pneumonia_viral/person21_virus_52.jpeg
# 0 pneumonia_viral/person21_virus_53.jpeg
# 3 pneumonia_viral/person22_virus_54.jpeg
# 0 pneumonia_viral/person22_virus_55.jpeg
# 3 pneumonia_viral/person23_virus_56.jpeg
# 3 pneumonia_viral/person24_virus_58.jpeg
# 3 pneumonia_viral/person25_virus_59.jpeg
# 3 pneumonia_viral/person26_virus_60.jpeg
# 3 pneumonia_viral/person28_virus_62.jpeg
# 3 pneumonia_viral/person28_virus_63.jpeg
# 3 pneumonia_viral/person29_virus_64.jpeg
# 3 pneumonia_viral/person30_virus_69.jpeg
# 3 pneumonia_viral/person31_virus_70.jpeg
# 3 pneumonia_viral/person32_virus_71.jpeg
# 3 pneumonia_viral/person33_virus_72.jpeg
# 3 pneumonia_viral/person3_virus_15.jpeg
# 3 pneumonia_viral/person3_virus_16.jpeg
# 3 pneumonia_viral/person3_virus_17.jpeg
# 2 pneumonia_viral/person8_virus_27.jpeg
# 1 pneumonia_viral/person8_virus_28.jpeg
# [38, 110, 71, 61]

# %% [markdown]
# ### **`Predict Results using predict generator and evaluate the accuracy and Confusion matrix `**

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import plot_confusion_matrix
from sklearn.metrics import classification_report



filenames = eval_generator.filenames
nb_samples = len(filenames)
eval_generator.reset()  
predict = model.predict_generator(eval_generator,steps = np.ceil(len(eval_generator)))
pp=predict
predict=np.argmax(predict, axis=-1)
classes= eval_generator.classes[eval_generator.index_array]
acc=sum(predict==classes)/len(predict)
names=["covid","normal","pneumonia_bac","pneumonia_vir"]
#print(confusion_matrix(classes,predict))

font = {
'family': 'Times New Roman',
'size': 12
}
plt.rc('font', **font)
cm = confusion_matrix(classes, predict)
print(cm)
print(classification_report(classes,predict))
plt.imshow(cm, cmap=plt.cm.Blues)
plt.xlabel('Predicted labels \nAccuracy: {:0.2f}'.format(acc*100))
plt.ylabel("True labels")
plt.xticks(classes, [])
plt.yticks(classes, [])
plt.title('Confusion matrix ')
plt.colorbar()
plt.show()
# Out:
# WARNING:tensorflow:From <ipython-input-16-9d55c32f16e7>:10: Model.predict_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.predict, which supports generators.
# [[33  2  0  0]
#  [ 1 97  0  2]
#  [ 0  7 61  7]
#  [ 4  4 10 52]]
#               precision    recall  f1-score   support
#
#            0       0.87      0.94      0.90        35
#            1       0.88      0.97      0.92       100
#            2       0.86      0.81      0.84        75
#            3       0.85      0.74      0.79        70
#
#     accuracy                           0.87       280
#    macro avg       0.87      0.87      0.86       280
# weighted avg       0.87      0.87      0.87       280
# findfont: Font family ['Times New Roman'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['Times New Roman'] not found. Falling back to DejaVu Sans.
